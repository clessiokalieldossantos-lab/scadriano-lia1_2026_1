# %% [markdown]
# <a href="https://colab.research.google.com/github/clessiokalieldossantos-lab/scadriano-lia1_2026_1/blob/main/Projeto_de_App_com_Yollo_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok

# %%
# !pip install onnxruntime opencv-python pillow matplotlib numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 80.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# - UPLOAD DO MODELO

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce7b4b79-1bff-4894-b1f3-c320d845a43c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce7b4b79-1bff-4894-b1f3-c320d845a43c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import onnxruntime as ort
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
CLASS_NAMES = ["Estragado", "Maduro", "Verde"]

# %%
session = ort.InferenceSession('best.onnx')
input_name = session.get_inputs()[0].name
# Out:
# ---------------------------------------------------------------------------
# NoSuchFile                                Traceback (most recent call last)
# /tmp/ipykernel_11263/721655595.py in <cell line: 0>()
# ----> 1 session = ort.InferenceSession('best.onnx')
#       2 input_name = session.get_inputs()[0].name
#
# /usr/local/lib/python3.12/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py in __init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     527
#     528         try:
# --> 529             self._create_inference_session(providers, provider_options, disabled_optimizers)
#     530         except (ValueError, RuntimeError) as e:
#     531             if self._enable_fallback:
#
# /usr/local/lib/python3.12/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py in _create_inference_session(self, providers, provider_options, disabled_optimizers)
#     622
#     623         if self._model_path:
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6efc5215-0b28-42e5-8a1b-63c24485a069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6efc5215-0b28-42e5-8a1b-63c24485a069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir('.'))
# Out:
# ['.config', 'Imagem de frutas - Classificação (1).jpg', 'material_escolar_ imagem.jpg', 'Imagem de frutas - Classificação.jpg', 'sample_data']

# %%
img = cv2.imread('Imagem de frutas - Classificação (1).jpg')
img_resized = cv2.resize(img, (640, 640))
img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)

img_input = img_rgb.astype(np.float32) / 255.0
img_input = np.transpose(img_input, (2, 0, 1))
img_input = np.expand_dims(img_input, axis=0)

# %%
outputs = session.run(None, {input_name: img_input})
output = outputs[0][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11263/1468635681.py in <cell line: 0>()
# ----> 1 outputs = session.run(None, {input_name: img_input})
#       2 output = outputs[0][0]
#
# NameError: name 'session' is not defined

# %%
boxes = []
scores = []
class_ids = []

for det in output:
    x, y, w_box, h_box = det[:4]
    conf = det[4]

    class_scores = det[5:]
    class_id = np.argmax(class_scores)
    score = conf * class_scores[class_id]

    if score > 0.25:
        bx = int((x - w_box/2) * w)
        by = int((y - h_box/2) * h)
        bw = int(w_box * w)
        bh = int(h_box * h)

        boxes.append([bx, by, bw, bh])
        scores.append(float(score))
        class_ids.append(class_id)

# NMS
indices = cv2.dnn.NMSBoxes(boxes, scores, 0.25, 0.45)

# desenhar resultados
for i in indices:
    i = i[0]
    x, y, bw, bh = boxes[i]
    label = f"{CLASS_NAMES[class_ids[i]]}: {scores[i]:.2f}"

    cv2.rectangle(img, (x, y), (x+bw, y+bh), (0,255,0), 2)
    cv2.putText(img, label, (x, y-10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 2)

# mostrar imagem
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11263/1552067350.py in <cell line: 0>()
#       3 class_ids = []
#       4
# ----> 5 for det in output:
#       6     x, y, w_box, h_box = det[:4]
#       7     conf = det[4]
#
# NameError: name 'output' is not defined
